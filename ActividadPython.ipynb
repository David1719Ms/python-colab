# %% [markdown]
# <a href="https://colab.research.google.com/github/David1719Ms/python-colab/blob/main/ActividadPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Actividad 1

# %%
# Ejercicio 1

v = int(input("Ingrese la velocidad: "))
t = int(input("Ingrese el tiempo: "))

d = v * t

print(f"La distancia recorrida por el vehiculo es: {d}Km")

# Ejercicio 2
nota1 = float(input("Ingrese la nota 1: "))
nota2 = float(input("Ingrese la nota 2: "))
nota3 = float(input("Ingrese la nota 3: "))

notaS = nota1 + nota2 + nota3
notaFinal = notaS/3

print(f"La nota final del estudiante es: {notaFinal}")

# Ejercicio 3
pGan = int(input("Ingrese la cantidad de partidos ganados: "))
pEmp = int(input("Ingrese la cantidad de partidos empatados: "))
pPer = int(input("Ingrese la cantidad de partidos perdidos: "))

win = 3
per = 0
emp = 1

victorias = pGan * win
perdidas = pPer * per
empates = pEmp * emp


puntosTotales = victorias + perdidas + empates

print(f"La cantidad de victorias del equipo son: {victorias}")
print(f"La cantidad de peridas del equipo son: {perdidas}")
print(f"La cantidad de empates del equipo son: {empates}")


print(f"La cantidad de puntos del equipo es: {puntosTotales}")

# Ejercicio 4
nombreEmpleado = input("Ingrese el nombre del empleado: ")
horasLabo = int(input("Ingrese la cantidad de horas laboradas en el mes: "))
tarifaHora = int(input("Ingrese la tarifa por hora: "))

totalDevengado = horasLabo * tarifaHora
print(nombreEmpleado)
print(horasLabo)
print(totalDevengado)

# Ejercicio 5
import math
a = int(input("Ingrese el tamaño del lado 1: "))
b = int(input("Ingrese el tamaño del lado 2: "))

h = math.sqrt(a**2 + b**2)

print(f"La hipotenusa es: {h}")

# Ejercicio 6

celsius = int(input("Ingrese la temperatura en C°: "))

farenheit = (celsius * 1.8) + 32


print(farenheit)
# Out:
# Ingrese la velocidad: 50
# Ingrese el tiempo: 40
# La distancia recorrida por el vehiculo es: 2000Km

# %% [markdown]
# Actividad 2

# %%
# Ejercicio 1
num1 = float(input("Ingrese un numero: "))

if num1 < 0:
    print(num1, num1.__abs__())

# Ejercicio 2
nota = float(input("Ingrese la nota: "))

if nota > 3:
    print("Aprobado")
else:
    print("Reprobado")

#Ejercicio 3
sueldoEmpleado = float(input("Ingrese el sueldo del empleado: "))
# sueldoTotal = 0

if sueldoEmpleado < 300000:
    sueldoTotal = sueldoEmpleado * 0.15
    print(sueldoTotal)
else:
    print("No aplica al aumento")

# Ejercicio 4
for i in range(5):
        categoria = input("Ingrese su categoria: ")
        match categoria:
                case 'Pobre':
                 empleados = 13000000
                 print(f"El sueldo segun la categoria {categoria}, es de: ${empleados}")
                case 'Medio':
                 empleados = 30000000
                 print(f"El sueldo segun la categoria {categoria}, es de: ${empleados}")
                case 'Rico':
                  empleados = 900000000
                  print(f"El sueldo segun la categoria {categoria}, es de: ${empleados}")


# Ejercicio 5
num1 = int(input("Ingrese el primer numero: "))
num2 = int(input("Ingrese el segundo numero: "))
num3 = int(input("Ingrese el tercer numero: "))


if num1 > num2 and num1 > num3:
    print(num1,num2,num3)
    print("El numero 1 es mayor")
elif num2 > num1 and num2 > num3:
    print(num1,num2,num3)
    print("El numero 2 es el mayor")
elif num3 > num2 and num3 > num1:
    print(num1,num2,num3)
    print("El numero 3 es mayor")
else:
    print("Todos los numeros son iguales")

if num1 == num2:
    print(f"Numero uno {num1} es igual al numero dos {num2}")
elif num1 == num3:
    print(f"Numero uno {num1} es igual al numero dos {num3}")
elif num2 == num3:
    print(f"Numero uno {num2} es igual al numero dos {num3}")





# Ejercicio 6
entrada = input("Ingrese la temperatura en C°: ")

try:
    valor = float(entrada)
    kelvin = valor + 273.15
    if kelvin > 10.5:
        print(f"La cantidad de grados kelvin {kelvin}, supera los 10.5")
    else:
        print(f"La cantidad de grados kelvin {kelvin} no supera los 10.5")
except ValueError:
    print(f"Ingresaste el caracter: {entrada}")

# Ejercicio 7

nombre = input("Ingrese el nombre: ")
edad = int(input("Ingrese la edad: "))
sexo = input("Ingrese el sexo: ")
estado = input("Ingrese el estado civil: ")

if sexo == 'Masculino' and estado == 'Casado' and edad > 40:
    print(f"Hola {nombre} tienes {edad} años y tu estado civil es {estado}")
elif sexo == 'Femenino' and estado == 'Soltera' and edad < 40:
    print(f"Hola {nombre} tienes {edad} años y tu estado civil es {estado}")
else:
    print(f"Hola {nombre} de sexo {sexo}, tienes {edad} años, y estás {estado}")

# Ejercicio 8
num1 = 99
num2 = 80
num3 = 90

if (num3 > num1 and num3 < num2) or num3 < num1 and num3 > num2:
    print(f"El numero del medio es el {num3}")
elif (num1 > num2 and num1 < num3) or num1 < num2 and num1 > num3:
    print(f"el numero del medio es el {num1}")
elif (num2 > num1 and num2 < num3) or num2 < num1 and num2 > num3:
    print(f"el numero del medio es el {num2}")
else:
    print("Todos los numeros son iguales")

# Ejercicio 9
numeros = [6,20,15]
numeros.sort()
print("Lista ordenada de menor a mayor:")
print(numeros)
numeros.reverse()
print("Lista de mayor a menor:")
print(numeros)

# Ejercicio 10
nota1 = float(input("Ingrese la nota 1: "))
nota2 = float(input("Ingrese la nota 2: "))
nota3 = float(input("Ingrese la nota 3: "))

if 1 <= nota1 <= 5 and 1 <= nota2 <= 5 and 1 <= nota3 <= 5:
    notas = [nota1, nota2, nota3]

    notas.sort(reverse=True)

    promedio = (notas[0] + notas[1]) / 2

    print("La nota final es:", promedio)
else:
    print("NO SE PUEDEN PONER NOTAS MENORES A 0")




# Ejercicio 11
longitud = float(input("Ingrese la longitud de la varilla: "))
densidad = 3.5

if longitud < 7.5:
    print(f"La longitud no puede ser menor a 7.5")
elif longitud > 9:
    print(f"La longitud no puede ser mayor a 9")
else:
    print("La longitud ingresada es correcta!")
diametro = float(input("Ingrese el valor del diametro: "))

if diametro < 0.5:
    print(f"El diametro ingresado no puede ser menor a 0.5")
elif diametro > 1.3:
    print(f"El diametro no puede ser mayor a 1.3")
else:
    print("El diametro ingresado es correcto!")

masa = diametro * longitud / densidad

if masa > 5.8:
    print("La masa no debe exceder los 5.8")
else:
    print(masa)
    print("Material Aceptado")

# Ejercicio 12
ventas = []
ventasMenores = 0
ventasMayores = 0
comisionTotal = 0

for i in range(5):
    venta = int(input(f"Ingrese el valor de la venta {i+1}: "))
    ventas.append(venta)

for venta in ventas:
    if venta < 2000:
        ventasMenores += 1
        comisionTotal += venta * 0.03
    else:
        ventasMayores += 1
        comisionTotal += venta * 0.05

# Mostrar resultados
print("Ventas menores de $2000:", ventasMenores)
print("Ventas mayores o iguales a $2000:", ventasMayores)
print("Comisión total:", comisionTotal)

# Ejercicio 13
rap1 = float(input("Ingrese el resultado de aprendizaje 1: "))
rap2 = float(input("Ingrese el resultado de aprendizaje 2: "))
rap3 = float(input("Ingrese el resultado de aprendizaje 3: "))

notaS = rap1 + rap2 + rap3
notaFinal = notaS / 3

if notaFinal > 3.1:
    print(f"El estudiante fue aprobado! con la nota de {notaFinal}")
else:
    print(f"El estudiante reporobó con nota {notaFinal}")

# Ejercicio 14
numero = int(input("Ingrese un número: "))
if numero != 0:
    resultado = 1 / numero
    print(f"El resultado de 1/{numero} es: {resultado}")
else:
    print("No se puede dividir entre cero.")

# Ejercicio 15
import math

a = float(input("Ingrese el valor de a: "))
b = float(input("Ingrese el valor de b: "))
c = float(input("Ingrese el valor de c: "))

discriminante = b**2 - 4*a*c

if discriminante >= 0:
    raiz1 = (-b + math.sqrt(discriminante)) / (2*a)
    raiz2 = (-b - math.sqrt(discriminante)) / (2*a)
    print(f"Las raíces son: {raiz1} y {raiz2}")
else:
    print("No tiene raíces reales.")

# Ejercicio 16
numero = int(input("Ingrese un numero: "))

if numero %2 == 0:
    print(f"el numero {numero} es par")
else:
    print(f"el numero {numero} es impar")

# Ejercicio 17
num1 = int(input("Ingrese el primer número: "))
num2 = int(input("Ingrese el segundo número: "))
num3 = int(input("Ingrese el tercer número: "))

divisibles = []

if num1 % num2 == 0:
    divisibles.append(f"{num1} es divisible por {num2}")
if num1 % num3 == 0:
    divisibles.append(f"{num1} es divisible por {num3}")
if num2 % num1 == 0:
    divisibles.append(f"{num2} es divisible por {num1}")
if num2 % num3 == 0:
    divisibles.append(f"{num2} es divisible por {num3}")
if num3 % num1 == 0:
    divisibles.append(f"{num3} es divisible por {num1}")
if num3 % num2 == 0:
    divisibles.append(f"{num3} es divisible por {num2}")

if divisibles:
    for resultado in divisibles:
        print(resultado)
else:
    print("Ninguno de los números es divisible")


# Ejercicio 18
numero = int(input("Ingrese un numero: "))

if numero < 0:
    print(f"El numero {numero} es negativo")
else:
    print(f"El numero {numero} es positivo")
